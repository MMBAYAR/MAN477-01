# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/MAN477-01/blob/main/Videos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ce2dcc5-a634-40d4-b154-3791c8f5a179" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ce2dcc5-a634-40d4-b154-3791c8f5a179">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Report.pdf to Report.pdf

# %%
Image("M477Syl.png",width = 500)

# %%
#@title Some python & linux magic...
# !wget http://commondatastorage.googleapis.com/gtv-videos-bucket/sample/VolkswagenGTIReview.mp4
# !mv VolkswagenGTIReview.mp4 video.mp4

# !pip install -U kora

from IPython.display import HTML
from kora.drive import upload_public

url = upload_public('video.mp4')
# HTML(f"""<video src={"https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/CapsimCore_How_To_Run_Your_Company_platform_final.mp4"} width=500 controls/>""")
# Out:
# --2022-09-11 14:18:02--  http://commondatastorage.googleapis.com/gtv-videos-bucket/sample/VolkswagenGTIReview.mp4
# Resolving commondatastorage.googleapis.com (commondatastorage.googleapis.com)... 142.251.162.128, 2607:f8b0:400c:c38::80
# Connecting to commondatastorage.googleapis.com (commondatastorage.googleapis.com)|142.251.162.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43780763 (42M) [video/mp4]
# Saving to: ‘VolkswagenGTIReview.mp4’
#
# VolkswagenGTIReview 100%[===================>]  41.75M  --.-KB/s    in 0.1s
#
# 2022-09-11 14:18:02 (387 MB/s) - ‘VolkswagenGTIReview.mp4’ saved [43780763/43780763]
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#@title CapsimCore Welcome Video
HTML(f"""<video src={
  "https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/Welcome_to_CapsimCore_Update.mp4"
  } width=1600 controls/>""")
# Out:
# <video src=https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/Welcome_to_CapsimCore_Update.mp4 width=1600 controls/>

# %%
#@title How to Run Your Company Video
HTML(f"""<video src={
  "https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/CapsimCore_How_To_Run_Your_Company_platform_final.mp4"
} width=1600 controls/>""")
# Out:
# <video src=https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/CapsimCore_How_To_Run_Your_Company_platform_final.mp4 width=1600 controls/>

# %% [markdown]
# `video controls src="https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/CapsimCore_How_To_Run_Your_Company_platform_final.mp4" /`
