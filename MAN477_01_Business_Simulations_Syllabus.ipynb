# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/MAN477-01/blob/main/MAN477_01_Business_Simulations_Syllabus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **MAN477-01 BUSINESS SIMULATIONS**
#
# (Mon., 12.3o - 15.2o @ LAB207)
# <br><br>
# **Course Instructor:** Mustafa Mehmet BAYAR
# <br>**Office Hours:** *To be determined with enrolled students:* https://shorturl.at/gPQX9
# <br>**Emaila:** mehmet.bayar@hbv.edu.tr
# <br>**Address:** Ankara Hacı Bayram Veli University, School of Economics and Administrative Sciences, Dept. of Business Administration, Room:212
# <br><br>
# ###**Course Definition**
# Teaching to run a manufacture company via a game (CapsimCore) based on the simulating the dynamics of a competitive environment.
# <br><br>
# ###**Course Objectives**
# The aim of this course is to provide the most concrete realization of theoretical courses taken in the first three years of business education in an online simulation environment. With the help of this course, students are expected to recognize the complexity of business life caused by internal and external factors and to understand how to cope with this complexity and how to be successful as a team member.
# <br><br>
# ###**Learning Outcomes**
# The students who succeeded in this course;
#
# * Understand the complex structure of the business environment,
# * Know the factors that measure the success of an enterprise,
# * Understand the importance of internal and external factors on decisions,
# * Form an awareness on the knowledge and skills required to become a strong team player.<br><br>
#
#
# ###**Teaching Strategies**
# * Team effort,
# * Case studies,
# * Debate<br><br>
#
# ###**Required Readings & Recommended Resources**
# * $\begin{matrix} \mathbf{[1]} & : & CapsimCore\ User\ Guide \end{matrix}$
# * $\begin{matrix} \mathbf{[2]} & : & CapsimCore\ 6\ Basic\ Strategies \end{matrix}$
# * $\begin{matrix} \mathbf{[3]} & : & CapsimCore\ Welcome\ Video \end{matrix}$
# * $\begin{matrix} \mathbf{[4]} & : & CapsimCore\ How\ to\ Run\ Your\ Company\ Video \end{matrix}$
# * $\begin{matrix} \mathbf{[5]} & : & Course\ handouts \end{matrix}$<br><br>
# ---
# \[1]: https://github.com/MMBAYAR/MAN477-01/blob/main/UserGuide_Core.pdf
# <br>[2]: https://github.com/MMBAYAR/MAN477-01/blob/main/SixBasicStrategies.pdf
# <br>[3]: https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/Welcome_to_CapsimCore_Update.mp4
# <br>[4]: https://downstream-to-capsim-customers.s3.amazonaws.com/production/videos/Cornerstone/CapsimCore/CapsimCore_How_To_Run_Your_Company_platform_final.mp4
# <br>[5]: To be distributed in class.
#
# ---
# <br>
# ###**Tentative Course Flow**<br>
# $\begin{array}{lll}
# \  & \mathbf{Content} & \mathbf{Preperation}\\
# \mathbf{Week\ 1} & What\ is\ the\ Game\ About? & [3],[5]\\
# \mathbf{Week\ 2} & Balanced\ Scorecard & [5]\\
# \mathbf{Week\ 3} & \begin{array}{ll}
# Marketing\ decisions: & Market analysis,\ positioning,\ product\ development,\ pricing,\\
# \ & distribution,\ communication
# \end{array} & [1],[2],[5]\\
# \mathbf{Week\ 4} & Operations\ decisions:\ Capacity\ decisions,\ demand\ forecasting,\ product\ and\ process\ design\ & [1],[2],[5]\\
# \mathbf{Week\ 5} & Finance\ decisions:\ Financial\ Table\ Analysis,\ Ratio\ analysis\ & [1],[2],[5]\\
# \mathbf{Week\ 6} & Demo\ Rounds\ and\ Assessment & [1],[2],[4]\\
# \mathbf{Week\ 7} & Round1\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 8} & Round2\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 9} & Round3\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 10} & Round4\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 11} & Round5\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 12} & Round6\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 13} & Round7\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 14} & Round8\ Results\ and\ Evaluation & [1],[2],[4]\\
# \mathbf{Week\ 15} & Presentations\ and\ Report\ Submissions & -\\
# \end{array}$<br><br>
#
# ###**Evaluation System**
# Team efforts will be the basis of the final grading. In detail, in-group peer evalutions, reports on justification of business decisions, and game performance will be evaluated while grading individuals.
# * For each decision category, students are to prepare reports on their "6 thinking hats" roles and justifying each decision. These reports will be written in standard fonts&size with 1.5 line spacing. **(Constitutes 80% of final grades)**
# * Game performance for each period will be measured with a 5-star metric. **(Constitutes 20% of final grades)**<br><br>
#
# **P.S.:** Worst game performance of each group will not be taken into consideration in final grading.<br><br>
#
# ###**Absence**
# Absence behavior will not effect the final grading. Yet, due to the school regulation absence will be recorded.<br>See Article 18,<br>
# https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=23659&MevzuatTur=8&MevzuatTertip=5
# <br><br>
#
# ###**Grading**
# See Article 21/6,<br>
# https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=23659&MevzuatTur=8&MevzuatTertip=5
# <br><br>
#
# ###**Code of Ethics**
# For all fellow students, ethics is the most critical concern. Thus, no student enrolled in this course shall interact with other groups while deciding their periodic strategy and while preparing their reports. Plus, all reports must be prepared with **individual efforts** of those who gave the corresponding decisions.<br><br> For those who shall violate the ethical code (cheating, plagiarism, etc.) will be held accountable for their actions.
# <br>See Article 20,<br>
# https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=23659&MevzuatTur=8&MevzuatTertip=5
# <br><br>
# **P.S.:** Aiding free riders will be considered as a violation of the code of ethics.
# <br><br>
#
# ###**Reserved Rights**
# Instructors right to alter this cyllabus partially or completely is reserved. In such cases students will be informed before changes are made effective.
# <br><br>
#
# ###**Course Outcomes**
#
# 1. Attainment of applied current-state-analysis skills for business administration,
# 2. Attainment of applied competition analysis skills for business administration,
# 3. Attainment of applied decision analysis skills for business administration.
# <br><br>
#
# ###**Program Outcomes**
# Please see.<br>https://www.atilim.edu.tr/en/management/page/5202/educational-objectives<br>and<br>https://www.atilim.edu.tr/tr/management/page/5202/ogrenme-ciktilari
# <br><br>
#
# ###**Course-Program Outcome Correspondence**
#
# \begin{matrix}
# \mathbf{Course\\Outcomes}&\mathbf{Program\ Outcomes}\\
# \begin{array}{l}
# \ \\
# \mathbf{C1}\\
# \mathbf{C2}\\
# \mathbf{C3}\\
# \mathbf{Overall}
# \end{array} & \begin{array}{cccccccccccc}
# \mathbf{P1} & \mathbf{P2} & \mathbf{P3} & \mathbf{P4} & \mathbf{P5} & \mathbf{P6} & \mathbf{P7} & \mathbf{P8} & \mathbf{P9} & \mathbf{P10} & \mathbf{P11} & \mathbf{P12}\\
# 5 & 5 & 3 & 3 & 4 & 5 & - & 4 & 4 & 4 & - & 4\\
# 4 & 5 & 4 & 4 & 5 & 5 & - & 5 & 4 & 3 & - & 5\\
# 5 & 4 & 5 & 3 & 5 & 4 & - & 4 & 5 & 3 & - & 5\\
# 5 & 5 & 4 & 3 & 5 & 5 & - & 4 & 4 & 3 & - & 5
# \end{array}
# \end{matrix}
